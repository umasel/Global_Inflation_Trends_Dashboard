# %% [markdown]
# # Database Connection

# %%
# Dependencies

import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %% [markdown]
# You will need to create a `.env` file in your project root directory and add the following environment variables:
#
# DB_USER=your_database_user
#
# DB_PASSWORD=your_database_password
#
# DB_HOST=your_database_host
#
# DB_PORT=your_database_port
#
# DB_NAME=your_database_name
#
# You will also need to add the .env file to your `.gitignore` file to prevent it from being tracked by Git. The .gitignore file should contain the following line:
#
# `.env`
#
# ---

# %% [markdown]
# In Windows Command Prompt:
#
# C:\Program Files\PostgreSQL\16\bin>psql -U postgres -h localhost -d global_inflation_db
# Password for user postgres:
#
# psql (16.3)
# WARNING: Console code page (437) differs from Windows code page (1252)
#          8-bit characters might not work correctly. See psql reference
#          page "Notes for Windows users" for details.
# Type "help" for help.
#
# global_inflation_db=#

# %%
# Load environment variables from .env file
load_dotenv()

# Get environment variables
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')

# Print environment variables to verify they are loaded correctly
print("DB_USER:", db_user)
print("DB_PASSWORD:", db_password)
print("DB_HOST:", db_host)
print("DB_PORT:", db_port)
print("DB_NAME:", db_name)

# %%
# Function to connect to DB
def connect_to_db():
    try:
        connection = psycopg2.connect(
            user=os.getenv('DB_USER'),
            password=os.getenv('DB_PASSWORD'),
            host=os.getenv('DB_HOST'),
            port=int(os.getenv('DB_PORT')),  # Convert port to integer
            database=os.getenv('DB_NAME')
        )
        return connection
    except Exception as error:
        print(f"Error: {error}")
        return None

# %%
# Create the database connection string
connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'

# Create a SQLAlchemy engine
engine = create_engine(connection_string)

# %%
# Save to .csv file
# Directory to save the extracted CSV files
output_directory = "C:\\Users\\wware\\Desktop\\UWA Bootcamp\\Challenges\\Global_Inflation_Trends_Dashboard\\1_integrated_code\\DB_Extraction"

# %%
# Function to fetch data, sort, and save to CSV
def fetch_data_and_save_to_csv(table_name):
    query = f"SELECT * FROM {table_name}"
    try:
        df = pd.read_sql_query(query, engine)
        if df is not None:
            print(f"\nData fetched successfully from {table_name}:")
            print(df.head())  # Print the first few rows of the DataFrame to verify
            
            # Sort the DataFrame by 'country' and then 'year' if the columns exist
            if 'country' in df.columns and 'year' in df.columns:
                df = df.sort_values(by=['country', 'year'])
            elif 'country' in df.columns:
                df = df.sort_values(by='country')
            elif 'year' in df.columns:
                df = df.sort_values(by='year')

            # High-level assessment
            print(f"\nHigh-level Assessment of {table_name} Data:")
            print(f"Number of records: {len(df)}")
            
            # Number of unique countries (if applicable)
            if 'country' in df.columns:
                num_countries = df['country'].nunique()
                print(f"Number of unique countries: {num_countries}")
            
            # Number of unique years (if applicable)
            if 'year' in df.columns:
                num_years = df['year'].nunique()
                print(f"Number of unique years: {num_years}")
            
            # Summary statistics for the dataset
            print(f"\nSummary statistics for {table_name} dataset:")
            print(df.describe())
            
            # Save the data to a CSV file
            output_path = os.path.join(output_directory, f"{table_name}.csv")
            df.to_csv(output_path, index=False)
            print(f"Data saved to {output_path}")
        else:
            print(f"Failed to fetch data from the {table_name} table.")
    except Exception as error:
        print(f"Error fetching data from {table_name}: {error}")

# List of tables to extract data from
tables = ['gdp', 'gdp_growth', 'gdp_percapita', 'gdp_ppp', 'gdp_ppp_percapita', 'gdp_unemployment', 'gdp_unemployment_by_category', 'inflation']

# Fetch data from each table and save to CSV
for table in tables:
    fetch_data_and_save_to_csv(table)
# Out:
# Data fetched successfully from gdp:
#                                  id                      country code  year  \
# 0                        Aruba_1960                        Aruba  ABW  1960
# 1  Africa Eastern and Southern_1960  Africa Eastern and Southern  AFE  1960
# 2                  Afghanistan_1960                  Afghanistan  AFG  1960
# 3   Africa Western and Central_1960   Africa Western and Central  AFW  1960
# 4                       Angola_1960                       Angola  AGO  1960
#
#             gdp
# 0           NaN
# 1  1.931311e+10
# 2  5.377778e+08
# 3  1.040428e+10
# 4           NaN
#
# High-level Assessment of gdp Data:
# Number of records: 16226
# Number of unique countries: 266
# Number of unique years: 61
#
# Summary statistics for gdp dataset:
#                year           gdp
# count  16226.000000  1.284000e+04
# mean    1990.000000  1.125492e+12
# std       17.607359  5.057450e+12
# min     1960.000000  8.824448e+06
# 25%     1975.000000  2.366667e+09
# 50%     1990.000000  1.755694e+10
# 75%     2005.000000  2.113418e+11
# max     2020.000000  8.756805e+13
# Data saved to C:\Users\wware\Desktop\UWA Bootcamp\Challenges\Global_Inflation_Trends_Dashboard\1_integrated_code\DB_Extraction\gdp.csv
#
# Data fetched successfully from gdp_growth:
# Empty DataFrame
# Columns: [id, country, code, year, gdp_growth]
# Index: []
#
# High-level Assessment of gdp_growth Data:
# Number of records: 0
# Number of unique countries: 0
# Number of unique years: 0
#
# Summary statistics for gdp_growth dataset:
#          id country code year gdp_growth
# count     0       0    0    0          0
# unique    0       0    0    0          0
# top     NaN     NaN  NaN  NaN        NaN
# freq    NaN     NaN  NaN  NaN        NaN
# Data saved to C:\Users\wware\Desktop\UWA Bootcamp\Challenges\Global_Inflation_Trends_Dashboard\1_integrated_code\DB_Extraction\gdp_growth.csv
#
# Data fetched successfully from gdp_percapita:
#                                  id                      country code  year  \
# 0                        Aruba_1960                        Aruba  ABW  1960
# 1  Africa Eastern and Southern_1960  Africa Eastern and Southern  AFE  1960
# 2                  Afghanistan_1960                  Afghanistan  AFG  1960
# 3   Africa Western and Central_1960   Africa Western and Central  AFW  1960
# 4                       Angola_1960                       Angola  AGO  1960
#
#    gdp_per_capita
# 0             NaN
# 1      147.612227
# 2       59.773234
# 3      107.932233
# 4             NaN
#
# High-level Assessment of gdp_percapita Data:
# Number of records: 16226
# Number of unique countries: 266
# Number of unique years: 61
#
# Summary statistics for gdp_percapita dataset:
#                year  gdp_per_capita
# count  16226.000000    12837.000000
# mean    1990.000000     7964.501931
# std       17.607359    16056.871409
# min     1960.000000       12.802812
# 25%     1975.000000      530.861039
# 50%     1990.000000     1810.619230
# 75%     2005.000000     7304.285771
# max     2020.000000   189487.147128
# Data saved to C:\Users\wware\Desktop\UWA Bootcamp\Challenges\Global_Inflation_Trends_Dashboard\1_integrated_code\DB_Extraction\gdp_percapita.csv
#
# Data fetched successfully from gdp_ppp:
#                                  id                      country code  year  \
# 0                        Aruba_1960                        Aruba  ABW  1960
# 1  Africa Eastern and Southern_1960  Africa Eastern and Southern  AFE  1960
# 2                  Afghanistan_1960                  Afghanistan  AFG  1960
# 3   Africa Western and Central_1960   Africa Western and Central  AFW  1960
# 4                       Angola_1960                       Angola  AGO  1960
#
#    gdp_ppp
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# High-level Assessment of gdp_ppp Data:
# Number of records: 16226
# Number of unique countries: 266
# Number of unique years: 61
#
# Summary statistics for gdp_ppp dataset:
#                year       gdp_ppp
# count  16226.000000  7.241000e+03
# mean    1990.000000  2.759214e+12
# std       17.607359  9.293424e+12
# min     1960.000000  1.374227e+07
# 25%     1975.000000  1.341124e+10
# 50%     1990.000000  8.439290e+10
# 75%     2005.000000  8.425623e+11
# max     2020.000000  1.348289e+14
# Data saved to C:\Users\wware\Desktop\UWA Bootcamp\Challenges\Global_Inflation_Trends_Dashboard\1_integrated_code\DB_Extraction\gdp_ppp.csv
#
# Data fetched successfully from gdp_ppp_percapita:
#                                  id                      country code  year  \
# 0                        Aruba_1960                        Aruba  ABW  1960
# 1  Africa Eastern and Southern_1960  Africa Eastern and Southern  AFE  1960
# 2                  Afghanistan_1960                  Afghanistan  AFG  1960
# 3   Africa Western and Central_1960   Africa Western and Central  AFW  1960
# 4                       Angola_1960                       Angola  AGO  1960
#
#    gdp_ppp_per_capita
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# High-level Assessment of gdp_ppp_percapita Data:
# Number of records: 16226
# Number of unique countries: 266
# Number of unique years: 61
#
# Summary statistics for gdp_ppp_percapita dataset:
#                year  gdp_ppp_per_capita
# count  16226.000000         7238.000000
# mean    1990.000000        14326.351258
# std       17.607359        17677.847021
# min     1960.000000          285.404911
# 25%     1975.000000         2875.298395
# 50%     1990.000000         7525.316313
# 75%     2005.000000        18717.529628
# max     2020.000000       153563.910960
# Data saved to C:\Users\wware\Desktop\UWA Bootcamp\Challenges\Global_Inflation_Trends_Dashboard\1_integrated_code\DB_Extraction\gdp_ppp_percapita.csv
#
# Data fetched successfully from gdp_unemployment:
#                                  id                      country code  year  \
# 0  Africa Eastern and Southern_1991  Africa Eastern and Southern  AFE  1991
# 1                  Afghanistan_1991                  Afghanistan  AFG  1991
# 2   Africa Western and Central_1991   Africa Western and Central  AFW  1991
# 3                       Angola_1991                       Angola  AGO  1991
# 4                      Albania_1991                      Albania  ALB  1991
#
#    unemployment_rate
# 0               7.80
# 1              10.65
# 2               4.42
# 3               4.21
# 4              10.31
#
# High-level Assessment of gdp_unemployment Data:
# Number of records: 7285
# Number of unique countries: 235
# Number of unique years: 31
#
# Summary statistics for gdp_unemployment dataset:
#               year  unemployment_rate
# count  7285.000000        7285.000000
# mean   2006.000000           8.006119
# std       8.944886           5.847902
# min    1991.000000           0.100000
# 25%    1998.000000           4.100000
# 50%    2006.000000           6.320000
# 75%    2014.000000          10.480000
# max    2021.000000          38.800000
# Data saved to C:\Users\wware\Desktop\UWA Bootcamp\Challenges\Global_Inflation_Trends_Dashboard\1_integrated_code\DB_Extraction\gdp_unemployment.csv
#
# Data fetched successfully from gdp_unemployment_by_category:
#                                           id      country  \
# 0        Afghanistan_Female_15-24_Youth_2014  Afghanistan
# 1         Afghanistan_Female_25+_Adults_2014  Afghanistan
# 2  Afghanistan_Female_Under 15_Children_2014  Afghanistan
# 3          Afghanistan_Male_15-24_Youth_2014  Afghanistan
# 4           Afghanistan_Male_25+_Adults_2014  Afghanistan
#
#                           indicator  gender age_group age_categories  year  \
# 0  Unemployment rate by sex and age  Female     15-24          Youth  2014
# 1  Unemployment rate by sex and age  Female       25+         Adults  2014
# 2  Unemployment rate by sex and age  Female  Under 15       Children  2014
# 3  Unemployment rate by sex and age    Male     15-24          Youth  2014
# 4  Unemployment rate by sex and age    Male       25+         Adults  2014
#
#    unemployment_rate
# 0             13.340
# 1              8.576
# 2             10.306
# 3              9.206
# 4              6.463
#
# High-level Assessment of gdp_unemployment_by_category Data:
# Number of records: 12474
# Number of unique countries: 189
# Number of unique years: 11
#
# Summary statistics for gdp_unemployment_by_category dataset:
#                year  unemployment_rate
# count  12474.000000       12444.000000
# mean    2019.000000          10.821359
# std        3.162404          10.620623
# min     2014.000000           0.027000
# 25%     2016.000000           3.773000
# 50%     2019.000000           7.092500
# 75%     2022.000000          14.058750
# max     2024.000000          83.990000
# Data saved to C:\Users\wware\Desktop\UWA Bootcamp\Challenges\Global_Inflation_Trends_Dashboard\1_integrated_code\DB_Extraction\gdp_unemployment_by_category.csv
#
# Data fetched successfully from inflation:
#                  id      country  \
# 0  Afghanistan_1980  Afghanistan
# 1      Albania_1980      Albania
# 2      Algeria_1980      Algeria
# 3      Andorra_1980      Andorra
# 4       Angola_1980       Angola
#
#                                          indicator  year  inflation_rate
# 0  Annual average inflation (consumer prices) rate  1980            13.4
# 1  Annual average inflation (consumer prices) rate  1980             NaN
# 2  Annual average inflation (consumer prices) rate  1980             9.7
# 3  Annual average inflation (consumer prices) rate  1980             NaN
# 4  Annual average inflation (consumer prices) rate  1980            46.7
#
# High-level Assessment of inflation Data:
# Number of records: 8820
# Number of unique countries: 196
# Number of unique years: 45
#
# Summary statistics for inflation dataset:
#               year  inflation_rate
# count  8820.000000     7952.000000
# mean   2002.000000       42.069447
# std      12.987909      861.118508
# min    1980.000000      -72.700000
# 25%    1991.000000        2.100000
# 50%    2002.000000        4.700000
# 75%    2013.000000       10.200000
# max    2024.000000    65374.100000
# Data saved to C:\Users\wware\Desktop\UWA Bootcamp\Challenges\Global_Inflation_Trends_Dashboard\1_integrated_code\DB_Extraction\inflation.csv
